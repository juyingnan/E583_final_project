# %%
from skimage import io
import matplotlib.pyplot as plt
import os
import numpy as np
# %matplotlib inline

# %%
img0 = io.imread('C:/Users/bunny/Desktop/images-227/apple.com/20040105094327.png')
img1 = io.imread('C:/Users/bunny/Desktop/images-227/apple.com/20040116144427.png')
img2 = io.imread('C:/Users/bunny/Desktop/images-227/apple.com/20040131052039.png')
img3 = io.imread('C:/Users/bunny/Desktop/images-227/apple.com/20040220064404.png')
img4 = io.imread('C:/Users/bunny/Desktop/images-227/apple.com/20040415063131.png')
img5 = io.imread('C:/Users/bunny/Desktop/images-227/apple.com/20040815082400.png')
img6 = io.imread('C:/Users/bunny/Desktop/images-227/apple.com/20040901081547.png')

img = (img0 // 7 + img1 // 7 + img2 // 7 +img3 // 7 +img4 // 7 +img5 // 7 +img6 // 7 ) 
plt.imshow(img)
